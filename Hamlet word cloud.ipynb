# %% [markdown]
# <a href="https://colab.research.google.com/github/showravj2-create/Real-world/blob/main/Hamlet%20word%20cloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install wordcloud

import requests
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Download Hamlet text from Project Gutenberg
url = "https://www.gutenberg.org/files/1524/1524-0.txt"
text = requests.get(url).text

# Generate word cloud
wordcloud = WordCloud(width=800, height=400, background_color="black",
                      colormap="plasma").generate(text)

# Show the visualization
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Word Cloud of Shakespeare's Hamlet ", fontsize=18, color="white")
plt.show()
